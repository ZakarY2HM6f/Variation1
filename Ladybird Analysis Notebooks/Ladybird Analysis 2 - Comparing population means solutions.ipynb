# %% [markdown]
# # Ladybird Analysis 2
#
# # Compare the mean sizes of melanic and non-melanic two-spot ladybird populations

# %% [markdown]
# <div class="alert alert-success">
#
# # Part 1: Exploring your data
# </div>

# %% [markdown]
# ## Task 1.2: Read in and print the data to check it is okay

# %%
import pandas as pd

ladybirds = pd.read_excel('ladybird_sizes_demo.xlsx')

ladybirds
# Out:
#    melanic  non-melanic
# 0      3.5          4.5
# 1      4.0          6.0
# 2      4.0          6.0
# 3      5.0          6.5
# 4      4.0          6.0
# 5      4.0          4.0
# 6      3.0          6.0
# 7      3.5          5.0
# 8      4.0          5.0
# 9      4.0          NaN

# %% [markdown]
# ## Task 1.3: Plot the samples in a histogram to see how they are distributed

# %%
import seaborn as sns

g = sns.displot(ladybirds)
g.ax.set_xlabel('Size (mm)')
g.ax.set_ylabel('Number of ladybirds')
g.ax.set_title('Sizes of two-spot ladybirds in low and high predation sites')
g.legend.set_title('Morph');

# %% [markdown]
# ## Task 1.4: The distributions might be clearer in a boxplot

# %%
g = sns.catplot(data=ladybirds, kind='box')
g.ax.set_ylabel('Size (mm)')
g.ax.set_xlabel('Morph')
g.ax.set_title('Sizes of two-spot ladybirds');

# %% [markdown]
# ## Task 1.5: What does the box and the various lines in a boxplot represent?

# %% [markdown]
# > The boxes represent the middle 50% of data. Also called the inter-quartile range. The horizontal line in the box is the median value. Half the data lie above it and half below it. The whiskers represent most of the rest of the data. Their lengths are 1.5 times the inter-quartile range.

# %% [markdown]
# ## Task 1.6: Eye-ball estimates of the means and standard deviations

# %% [markdown]
# - melanic mean is about 4mm
# - melanic $s$ is about (5-3)/4 = 0.5 mm
# - non-melanic mean is about 5.5mm
# - non-melanic $s$ is about (6.5-4)/4 = 0.625 mm

# %% [markdown]
# ## Task 1.7: Calculate the sample sizes, sample means and sample standard deviations

# %%
n = ladybirds.count()
xbar = ladybirds.mean()
s = ladybirds.std()

print('Sample sizes, n')
print(n)
print() # Blank line

print('Sample means to 2dp, xbar')
print(round(xbar, 2))
print() # Blank line

print('Sample standard deviations to 2dp, s')
print(round(s, 2))
# Out:
# Sample sizes, n
# melanic        10
# non-melanic     9
# dtype: int64
#
# Sample means to 2dp, xbar
# melanic        3.90
# non-melanic    5.44
# dtype: float64
#
# Sample standard deviations to 2dp, s
# melanic        0.52
# non-melanic    0.85
# dtype: float64

# %% [markdown]
# ## Task 1.8: Calculate the difference in the sample means

# %%
# calculate your observed d-statistic: difference in sample means

d = xbar['non-melanic'] - xbar['melanic']

print(f'difference in observed mean sizes = {d:.2f} mm')
# Out:
# difference in observed mean sizes = 1.54 mm

# %% [markdown]
# <div class="alert alert-success">
#
# # Part 2: Two-sample *t*-test
# </div>

# %% [markdown]
# ## Task 2.1: Perform a two-sample *t*-test

# %%
from scipy.stats import ttest_ind # import the two sample t-test function

# Perform the two sample t-test
t, p = ttest_ind(ladybirds['non-melanic'], ladybirds['melanic'], nan_policy='omit')

# Print the t-statistic to 2dp
print(f't-statistic = {t:.2f}')

# Print the p-value to 4dp
print(f'p-value = {p}')
# Out:
# t-statistic = 4.86
# p-value = 0.00014609710793957542

# %% [markdown]
# ## Task 2.2: Reject or not reject your null hypothesis

# %% [markdown]
# > p=0.0001 which is less than 0.05. We therefore reject the null hypothesis that the average size of melanic and non-melanic ladybirds are the same

# %% [markdown]
# ## Task 2.3: Report the result of your test

# %% [markdown]
# > Sizes of melanic and non-melanic two-spot ladybirds were measured in an Edinburgh cemetery.  A statistically significant difference was found of 1,54 mm (*t* = 4.86, *p* = 0.0001). This evidence does not support our hypothesis that temperature during development affects the sizes of ladybirds
